O jeito é dar uma fugidinha com você
O jeito é dar uma fugida com você
Se você quer saber o que vai acontecer
Primeiro a gente foge, depois a gente vê

O jeito é dar uma fugidinha com você
O jeito é dar uma fugida com você
Se você quer saber o que vai acontecer
Primeiro a gente foge, depois a gente vê

Tô bem na parada, ninguém consegue entender
Chego na balada, todos param pra me ver
Tudo dando certo, mas eu tô esperto
Não posso botar tudo a perder

Sempre tem aquela pessoa especial
Que fica na dela, sabe seu potencial
E mexe comigo, isso é um perigo
Logo agora que eu fiquei legal

Tô morrendo de vontade de te agarrar
Não sei quanto tempo mais vou suportar
Mas pra gente se encontrar ninguém pode saber
Já pensei e sei o que devo fazer

O jeito é dar uma fugidinha com você
O jeito é dar uma fugida com você
Se você quer saber o que vai acontecer
Primeiro a gente foge, depois a gente vê

O jeito é dar uma fugidinha com você
O jeito é dar uma fugida com você
Se você quer saber o que vai acontecer
Primeiro a gente foge, depois a gente vê

O jeito é dar uma fudidinha com você
O jeito é dar uma fudida com você
Se você quer saber o que vai acontecer
Primeiro a gente foge, depois a gente vê

O jeito é dar uma fugidinha com você
O jeito é dar uma fugida com você
Se você quer saber o que vai acontecer
Primeiro a gente foge, depois a gente vê

"""

# %%
import re
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from keras.layers import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential

# %%
def text_basic(texto):
    texto = re.sub(r'[\W\s\n]+', " ", texto)
    return texto.lower()

# %%
textos = [letra1, letra2, letra3, letra4, letra5, letra6, letra7, letra8, letra9, letra10]
textos = [text_basic(texto) for texto in textos]
textos = " ".join(textos)

# %%
textos[:1000]
# Out:
# 'a gente tinha combinado que já tava tudo errado e que não dava mais marcamos o ponto final mas o final é sempre igual você me faz voltar atrás enche de perfume no corpo e um sorriso que me deixa louco com a intenção de provocar como é que eu largo dela e a gente fez amor oh oh era pra terminar quem disse que eu consigo e a gente fez amor oh oh como se fosse o último pedido e a gente fez amor oh oh era pra terminar quem disse que eu consigo e a gente fez amor oh oh como se fosse o último pedido enche de perfume no corpo e um sorriso que me deixa louco com a intenção de provocar como é que eu largo dela enche de perfume no corpo e um sorriso que me deixa louco com a intenção de provocar e como é que eu largo dela e a gente fez amor oh oh era pra terminar quem disse que eu consigo e a gente fez amor oh oh como se fosse o último pedido e a gente fez amor oh oh era pra terminar quem disse que eu consigo e a gente fez amor oh oh como se fosse o último pedido enche de perfume no corpo e um so'

# %%
chars = set([c for c in textos])
nb_chars = len(chars)

# %%
# Cria um mapeamento de letras para números e vice-versa
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# %%
# Define o tamanho máximo da janela de texto como 15 caracteres
SEQLEN, STEP = 15, 1
input_chars, label_chars = [], []

# %%
# Converte os dados em uma série de subsequencias de tamanho 10
for i in range(0, len(textos) - SEQLEN, STEP):
    input_chars.append(textos[i: i + SEQLEN])
    label_chars.append(textos[i + SEQLEN])

# %%
# Cria o vetor one-hot encoding das sequencias de entradas (X) e o próximo caracter (y)
X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1

# %%
# Define os metaparametros para o treinamento da rede
BATCH_SIZE = 128
HIDDEN_SIZE = 128
NUM_ITERATIONS = 25
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 200

# %%
# Cria a rede. Existe uma camada recorrente que produz um embedding de tamanho 128 
# a partir de uma camada de entrada one-hot-encoded
# Essa camada é seguida por uma camada Dense fully-connected, que retorna a probabilidade de cada
# caractere no conjunto de caracteres possíveis de ser o próximo
model = Sequential()
model.add(
    LSTM(  
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")

# %%
# Treina o modelo
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Divide o dataset em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=True)

# %%
# Treina o modelo em batches e testa a saída gerada em cada step
EPOCS = 10

for iteration in range(EPOCS):
    print("=" * 50)
    print("Iteração #: {}".format(iteration))
    model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
# Out:
# ==================================================
# Iteração #: 0
# Epoch 1/1
# 9005/9005 [==============================] - 3s 343us/step - loss: 0.1128 - accuracy: 0.9714
# ==================================================
# Iteração #: 1
# Epoch 1/1
# 9005/9005 [==============================] - 2s 202us/step - loss: 0.1061 - accuracy: 0.9714
# ==================================================
# Iteração #: 2
# Epoch 1/1
# 9005/9005 [==============================] - 2s 202us/step - loss: 0.1023 - accuracy: 0.9714
# ==================================================
# Iteração #: 3
# Epoch 1/1
# 9005/9005 [==============================] - 2s 204us/step - loss: 0.0956 - accuracy: 0.9721
# ==================================================
# Iteração #: 4
# Epoch 1/1
# 9005/9005 [==============================] - 2s 205us/step - loss: 0.0898 - accuracy: 0.9734
# ==================================================
# Iteração #: 5
# Epoch 1/1
# 9005/9005 [==============================] - 2s 271us/step - loss: 0.0863 - accuracy: 0.9741
# ==================================================
# Iteração #: 6
# Epoch 1/1
# 9005/9005 [==============================] - 2s 264us/step - loss: 0.0830 - accuracy: 0.9749
# ==================================================
# Iteração #: 7
# Epoch 1/1
# 9005/9005 [==============================] - 2s 263us/step - loss: 0.0808 - accuracy: 0.9752
# ==================================================
# Iteração #: 8
# Epoch 1/1
# 9005/9005 [==============================] - 2s 261us/step - loss: 0.0785 - accuracy: 0.9758
# ==================================================
# Iteração #: 9
# Epoch 1/1
# 9005/9005 [==============================] - 2s 262us/step - loss: 0.0764 - accuracy: 0.9761

# %%
# Avalia o modelo
loss, accuracy = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=0)
print(model.metrics_names)
print("Accuracy: ", accuracy)
print("Loss: ", loss)
# Out:
# ['loss', 'accuracy']
# Accuracy:  0.9749865531921387
# Loss:  0.07951547006766001

# %%
# Insere o texto com 15 caracteres que será a seed para gerar a música
test_chars = 'amor da minha '

# Realiza a previsão dos próximos 200 caracteres
for i in range(NUM_PREDS_PER_EPOCH):
    Xtest = np.zeros((1, SEQLEN, nb_chars))
    for j, ch in enumerate(test_chars):
        Xtest[0, j, char2index[ch]] = 1
    pred = model.predict(Xtest, verbose=0)[0]
    ypred = index2char[np.argmax(pred)]
    
    # Exibe o próximo caracter previsto
    print(ypred, end="")
    
    # move adiante para o próximo caracter com test_chars + ypred
    test_chars = test_chars[1:] + ypred
# Out:
# e e eeee e egeeee e e eeeee e egeeee e e eeeee e egeeee e e eeeee e egeeee e e eeeee e egeeee e e eeeee e egeeee e e eeeee e egeeee e e eeeee e egeeee e e eeeee e egeeee e e eeeee e egeeee e e eeeee e
